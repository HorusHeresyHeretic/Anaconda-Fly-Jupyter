# %%
from __future__ import division, print_function
# отключим всякие предупреждения Anaconda
import warnings
warnings.filterwarnings('ignore')
# %matplotlib inline
from matplotlib import pyplot as plt
plt.rcParams['figure.figsize'] = (10, 8)
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.preprocessing import LabelEncoder
import collections
from sklearn.model_selection import GridSearchCV
from sklearn import preprocessing
from sklearn.tree import DecisionTreeClassifier, export_graphviz
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# %%
# работает, одна из самых быстрых (но не самая быстрая) и не прожорливых реализаций. стат фукнция на борту.
# теперь осталось подумать как обернуть результаты вывода в title исходя из списка фреймов, та ещё задача.

# %%
df_1 = pd.read_csv('J:/Data_mks/sub_rebills_2017-08-01_2017-08-31_f/sub_rebills_2017-08-01_2017-08-31_f.csv', sep='\t', encoding='utf-8')

# %%
# протопит: при вызове manual() возвращает последовательно по одному датафрейму, пустые не возвращает.
# по окончанию перебора датафеймоф возвращает звенящую пустоту, StopIteration по yield не возбуждает.

def select():
    Bexc = df_1[df_1['query'].str.contains('exchange=%7Bexc%7D', na=False)]
    BEXCHANGE_ID = df_1[df_1['query'].str.contains('exchange=BEXCHANGE_ID', na=False)]
    EXCHANGE_ID = df_1[df_1['query'].str.contains('exchange=EXCHANGE_ID', na=False)]
    axonix = df_1[df_1['query'].str.contains('exchange=axonix', na=False)]
    smartyads = df_1[df_1['query'].str.contains('exchange=smartyads', na=False)]
    undef = df_1[df_1['query'].str.contains('exchange=undef', na=False)]
    arteebee = df_1[df_1['query'].str.contains('exchange=arteebee', na=False)]
    between = df_1[df_1['query'].str.contains('exchange=between', na=False)]
    clickky = df_1[df_1['query'].str.contains('exchange=clickky', na=False)]
    google = df_1[df_1['query'].str.contains('exchange=google', na=False)]
    gothamads = df_1[df_1['query'].str.contains('exchange=gothamads', na=False)]
    mobilda = df_1[df_1['query'].str.contains('exchange=mobilda', na=False)]
    repeater = df_1[df_1['query'].str.contains('exchange=repeater', na=False)]
    republer = df_1[df_1['query'].str.contains('exchange=republer', na=False)]
    sape = df_1[df_1['query'].str.contains('exchange=sape', na=False)]  
    clickky2 = df_1[df_1['query'].str.contains('exchange=clickky2', na=False)]
    exoclick = df_1[df_1['query'].str.contains('exchange=exoclick', na=False)]
    popcash = df_1[df_1['query'].str.contains('exchange=popcash', na=False)]
    popunder = df_1[df_1['query'].str.contains('exchange=popunder', na=False)]
    propeller = df_1[df_1['query'].str.contains('exchange=propeller', na=False)]
    yabbi = df_1[df_1['query'].str.contains('exchange=yabbi', na=False)]
    activerevenue = df_1[df_1['query'].str.contains('exchange=activerevenue', na=False)]
    fallback = df_1[df_1['query'].str.contains('exchange=fallback', na=False)]
    innex = df_1[df_1['query'].str.contains('exchange=innex', na=False)]
    juicy = df_1[df_1['query'].str.contains('exchange=juicy', na=False)]
    airpush = df_1[df_1['query'].str.contains('exchange=airpush', na=False)]
    leadbolt = df_1[df_1['query'].str.contains('exchange=leadbolt', na=False)]
    something = df_1[df_1['query'].str.contains('exchange=something', na=False)]
    hilltop = df_1[df_1['query'].str.contains('exchange=hilltop', na=False)]
    propellerads = df_1[df_1['query'].str.contains('exchange=propellerads', na=False)]
    mobicow = df_1[df_1['query'].str.contains('exchange=mobicow', na=False)]
    openx = df_1[df_1['query'].str.contains('exchange=openx', na=False)]
    smaato = df_1[df_1['query'].str.contains('exchange=smaato', na=False)]
    tonic = df_1[df_1['query'].str.contains('exchange=tonic', na=False)]
    traffichunt = df_1[df_1['query'].str.contains('exchange=traffichunt', na=False)]
    zeropark = df_1[df_1['query'].str.contains('exchange=zeropark', na=False)]
    admobile = df_1[df_1['query'].str.contains('exchange=admobile', na=False)]
    tapxx = df_1[df_1['query'].str.contains('exchange=tapxx', na=False)]
    teasernet = df_1[df_1['query'].str.contains('exchange=teasernet', na=False)]
    visitweb = df_1[df_1['query'].str.contains('exchange=visitweb', na=False)]
    epom = df_1[df_1['query'].str.contains('exchange=epom', na=False)]
    plugrush = df_1[df_1['query'].str.contains('exchange=plugrush', na=False)]
    kadam = df_1[df_1['query'].str.contains('exchange=kadam', na=False)]
    minimob = df_1[df_1['query'].str.contains('exchange=minimob', na=False)]
    peakadx = df_1[df_1['query'].str.contains('exchange=peakadx', na=False)]
    print('Bexc', len(Bexc), 'axonix', len(axonix), 'smartyads', len(smartyads), 'undef', len(undef),'arteebee', len(arteebee), 
                 'between', len(between), 'clickky', len(clickky), 'google', len(google), 'gothamads',len(gothamads), 'mobilda',len(mobilda),
                 'repeater',len(repeater), 'republer', len(republer), 'sape', len(sape), 'clickky2', len(clickky2),'exoclick',len(exoclick),
                 'popcash',len(popcash), 'popunder',len(popunder), 'propeller',len(propeller), 'yabbi',len(yabbi), 'activerevenue', len(activerevenue),
                'fallback', len(fallback), 'innex', len(innex), 'juicy',len(juicy), 'airpush', len(airpush), 'leadbolt', len(leadbolt),
                 'something', len(something), 'hilltop',len(hilltop), 'propellerads',len(propellerads), 'mobicow', len(mobicow),'openx',len(openx),
                 'smaato',len(smaato), 'tonic',len(tonic), 'traffichunt',len(traffichunt), 'zeropark', len(zeropark), 'admobile', len(admobile),
                 'tapxx', len(tapxx), 'teasernet', len(teasernet), 'visitweb', len(visitweb), 'BEXCHANGE_ID',len(BEXCHANGE_ID),
                 'EXCHANGE_ID',len(EXCHANGE_ID) ,'epom', len(epom), 'plugrush',len(plugrush), 'kadam', len(kadam),
                  'minimob', len(minimob), 'peakadx', len(peakadx), 'a_propellerads', len(a_propellerads))
    return Bexc,BEXCHANGE_ID,EXCHANGE_ID,axonix,smartyads,undef,arteebee,between,clickky,google,gothamads,mobilda,repeater,republer,sape,clickky2,exoclick, popcash,popunder,propeller,yabbi,activerevenue,fallback,innex,juicy,airpush, leadbolt,
    something, hilltop,propellerads,mobicow,openx, smaato, tonic,traffichunt,zeropark,admobile,tapxx,teasernet,visitweb, epom,
    plugrush,kadam, minimob,peakadx,a_propellerads

def warp_field_generator():
    for pony in select():
        yield pony

warp_portal = warp_field_generator()   

def manual():
    for pony in warp_portal:
        if len(pony) > 0:
            return pony

# %%
manual()
# Out:
#                                     sub_uuid  service_id         URL  \
# 638986  3604aa2c-7b9e-11e7-953f-bf57dddfe09a         933  Амедиатека
# 638990  36409af0-7b9e-11e7-aa3e-c157dddfe09a         933  Амедиатека
#
#        Подключение  Юр.лицо  ОСС            date_init date_activation  \
# 638986   mks (478)  МКС ООО  МТС  2017-08-07 21:28:30             NaN
# 638990   mks (478)  МКС ООО  МТС  2017-08-07 21:28:30             NaN
#
#        date_stop  msisdn      ...        \
# 638986       NaN       0      ...
# 638990       NaN       0      ...
#
#                                                     query            ip  \
# 638986  utm_source=das&tmpl=amedia_def&utm_source=g2m&...  75.156.75.93
# 638990  utm_source=das&tmpl=amedia_def&utm_source=g2m&...  75.156.75.93
#
#                                                        ua error_code  \
# 638986  Mozilla/5.0 (Windows NT 10.0; Win64; x64) Appl
# 5000714   mks (478)  МКС ООО  МТС  2017-08-31 23:59:53             NaN
#
#         date_stop  msisdn      ...        \
# 0             NaN       0      ...
# 1             NaN       0      ...
# 12            NaN       0      ...
# 16            NaN       0      ...
# 20            NaN       0      ...
# 23            NaN       0      ...
# 29            NaN       0      ...
# 31            NaN       0      ...
# 33            NaN       0      ...
# 36            NaN       0      ...
# 46            NaN       0      ...
# 48            NaN       0      ...
# 51            NaN       0      ...
# 55            NaN       0      ...
# 76            NaN       0      ...
# 81            NaN       0      ...
# 83            NaN       0      ...
# 85            NaN       0      ...
# 89            NaN       0      ...
# 90            NaN       0      ...
# 103           NaN       0      ...
# 107           NaN       0      ...
# 110           NaN       0      ...
# 117           NaN       0      ...
# 118           NaN       0      ...
# 123           NaN       0      ...
# 124           NaN       0      ...
# 128           NaN       0      ...
# 132           NaN       0      ...
# 135           NaN       0      ...
# ...           ...     ...      ...
# 5000213       NaN       0      ...
# 5000249       NaN       0      ...
# 5000289       NaN       0      ...
# 5000292       NaN       0      ...
# 5000314       NaN       0      ...
# 5000339       NaN       0      ...
# 5000349       NaN       0      ...
# 5000372       NaN       0      ...
# 5000432       NaN       0      ...
# 5000454       NaN       0      ...
# 5000455       NaN       0      ...
# 5000517       NaN       0      ...
# 5000519       NaN       0      ...
# 5000548       NaN       0      ...
# 5000550       NaN       0      ...
# 5000573       NaN       0      ...
# 5000609       NaN       0      ...
# 5000614       NaN       0      ...
# 5000622       NaN       0      ...
# 5000632       NaN       0      ...
# 5000635       NaN       0      ...
# 5000656       NaN       0      ...
# 5000662       NaN       0      ...
# 5000663       NaN       0      ...
# 5000666       NaN       0      ...
# 5000671       NaN       0      ...
# 5000679       NaN       0      ...
# 5000698       NaN       0      ...
# 5000709       NaN       0      ...
# 5000714       NaN       0      ...
#
#                                                      query              ip  \
# 0        utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.4.140
# 1        utm_source=das&tmpl=amedia_def&exchange=axonix...    85.140.1.117
# 12       utm_source=das&tmpl=amedia_def&exchange=axonix...    85.140.79.95
# 16       utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.6.79
# 20       utm_source=das&tmpl=amedia_def&exchange=axonix...   85.140.78.248
# 23       utm_source=das&tmpl=amedia_got&exchange=axonix...  213.87.123.166
# 29       utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.0.11
# 31       utm_source=das&tmpl=amedia_def&exchange=axonix...  213.87.100.131
# 33       utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.3.59
# 36       utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.1.117
# 46       utm_source=das&tmpl=amedia_got2&exchange=axoni...    85.140.5.177
# 48       utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.0.35
# 51       utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.3.173
# 55       utm_source=das&tmpl=amedia_def&exchange=axonix...    85.140.4.140
# 76       utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.1.117
# 81       utm_source=das&tmpl=amedia_def&exchange=axonix...  213.87.127.215
# 83       utm_source=das&tmpl=amedia_got&exchange=axonix...     85.140.2.65
# 85       utm_source=das&tmpl=amedia_def&exchange=axonix...  213.87.123.186
# 89       utm_source=das&tmpl=amedia_got&exchange=axonix...  213.87.241.161
# 90       utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.1.111
# 103      utm_source=das&tmpl=amedia_def&exchange=axonix...    85.140.5.177
# 107      utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.1.125
# 110      utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.0.28
# 117      utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.4.140
# 118      utm_source=das&tmpl=amedia_def&exchange=axonix...    85.140.2.238
# 123      utm_source=das&tmpl=amedia_got&exchange=axonix...    85.140.1.174
# 124      utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.7.90
# 128      utm_source=das&tmpl=amedia_def&exchange=axonix...     85.140.3.56
# 132      utm_source=das&tmpl=amedia_got&exchange=axonix...      85.140.2.6
# 135      utm_source=das&tmpl=amedia_def&exchange=axonix...  213.87.124.228
# ...                                                    ...             ...
# 5000213  uuid=04f6f51b-50b6-4e00-99b5-28f4322b90dc&serv...   217.66.156.91
# 5000249  uuid=356fca43-a758-424a-8fa6-41213a4145b9&serv...  213.87.133.193
# 5000289  uuid=c8961966-ab73-4a20-85ab-edf7b032645c&serv...      85.140.2.6
# 5000292  uuid=5122f9ec-d4c3-4660-bedf-f2498805333d&serv...  95.153.133.108
# 5000314  uuid=307d0d49-a798-47b5-be1a-b1e3074caec2&serv...   213.87.151.99
# 5000339  uuid=f80b215d-fc53-4e69-8585-c02450164a46&serv...   213.87.136.98
# 5000349  uuid=3761dbe9-855e-42d1-a42c-7f55201b905c&serv...    85.140.1.155
# 5000372  uuid=b9d1d835-df59-4976-a9f6-a9d5556b580d&serv...   213.87.151.53
# 5000432  uuid=2beea3ce-f48c-40a1-a71a-619c94a19bf0&serv...   213.87.154.48
# 5000454  uuid=576bd8a3-9f44-4e32-a860-0a0d63196125&serv...   95.153.130.28
# 5000455  uuid=e5d2c055-77b3-456e-9711-644c2a702800&serv...    217.66.152.0
# 5000517  uuid=ce1cff50-cc61-437d-a008-682f536319ad&serv...  95.153.128.235
# 5000519  uuid=fb1d89f4-7531-4f7a-bedb-e36b2d49cf67&serv...  213.87.146.251
# 5000548  uuid=528673ec-d155-4dd6-98b8-d5a1c24ce4c8&serv...  217.66.156.226
# 5000550  uuid=c5faacf4-4092-45c0-a29b-6c0bd41c2ddc&serv...  213.87.248.132
# 5000573  uuid=e249558d-8571-467b-aea7-dd558751615c&serv...  217.66.152.192
# 5000609  uuid=6906df0f-cf6d-420a-8239-2dbdd15ce364&serv...  95.153.128.235
# 5000614  uuid=99e16544-ebe1-47d8-a02b-3ca47099dd18&serv...  213.87.159.240
# 5000622  uuid=81f0a09e-99c5-407f-89fa-caeec1f99e9c&serv...    85.140.2.120
# 5000632  uuid=3a11db79-6e01-4da8-9cc2-e516a7b0a645&serv...     85.140.1.46
# 5000635  uuid=7bb325d4-345c-4354-879e-abb4ba798c91&serv...  95.153.131.246
# 5000656  uuid=f47ea1a0-ec21-4dd1-8b6d-345a4c6bf85f&serv...   95.153.134.58
# 5000662  uuid=00ac2df7-c9a7-4d82-a423-751cc348621a&serv...  213.87.156.223
# 5000663  uuid=51e32beb-b85c-407e-895b-bd806acb59d2&serv...  213.87.153.143
# 5000666  uuid=77ad4144-d0a3-4586-8439-08a75f8313b2&serv...      85.140.2.6
# 5000671  uuid=6b4186ad-d3ff-4f52-b37f-a48dba2d21b0&serv...   95.153.128.73
# 5000679  uuid=f73c7d78-76f3-494c-a0c2-2a06b9ab629c&serv...    213.87.156.5
# 5000698  uuid=5ee2e5df-78a5-4c34-bdad-4729d71394b9&serv...    217.66.152.5
# 5000709  uuid=3f4e544d-314d-479a-aac2-93d6a57b04c8&serv...   213.87.153.26
# 5000714  uuid=d3e366b3-8438-45ed-88f2-166f0898fcc2&serv...  95.153.133.160
#
#                                                         ua error_code  \
# 0        Mozilla/5.0 (Linux; Android 6.0; U20 Build/MRA...          0
# 1        Mozilla/5.0 (Linux; Android 4.4.2; ASUS_T00J B...          0
# 12       Mozilla/5.0 (Linux; Android 5.1; HUAWEI CUN-U2...          0
# 16       Mozilla/5.0 (Linux; Android 5.1; Roverphone Bu...          0
# 20       Mozilla/5.0 (Linux; Android 5.0.2; SM-A500F Bu...          0
# 23       Mozilla/5.0 (Linux; Android 6.0; CRO-L22 Build...          0
# 29       Mozilla/5.0 (Linux; Android 4.4.2; ZTE Blade L...          0
# 31       Mozilla/5.0 (Linux; Android 4.4.2; GT-I9200 Bu...          8
# 33       Mozilla/5.0 (Linux; Android 6.0.1; MotoG3 Buil...          0
# 36       Mozilla/5.0 (Linux; Android 4.4.2; ASUS_T00J B...          0
# 46       Mozilla/5.0 (Linux; Android 4.4.4; Ixion X LTE...          0
# 48       Mozilla/5.0 (Linux; Android 5.0.2; ASUS_Z00LD ...          0
# 51       Mozilla/5.0 (Linux; Android 5.1; Micromax Q338...          0
# 55       Mozilla/5.0 (Linux; Android 6.0; U20 Build/MRA...          0
# 76       Mozilla/5.0 (Linux; Android 4.4.2; ASUS_T00J B...          0
# 81       Mozilla/5.0 (Linux; Android 4.4.2; ASUS_T00K B...          0
# 83       Mozilla/5.0 (Linux; U; Android 4.2.2; ru-ru; G...          0
# 85       Mozilla/5.0 (Linux; Android 5.1; Roverpad Buil...          0
# 89       Mozilla/5.0 (Linux; Android 5.1.1; NX512J Buil...          0
# 90       Mozilla/5.0 (Linux; U; Android 4.2.2; ru-ru; M...          0
# 103      Mozilla/5.0 (Linux; Android 4.4.4; Ixion X LTE...          0
# 107      Mozilla/5.0 (Linux; Android 5.1; Philips S337 ...          0
# 110      Mozilla/5.0 (Linux; Android 6.0; FS454 Build/M...          0
# 117      Mozilla/5.0 (Linux; Android 6.0; U20 Build/MRA...          0
# 118      Mozilla/5.0 (Linux; U; Android 4.3; ru-ru; GT-...          0
# 123      Mozilla/5.0 (Linux; Android 5.1; PSP5502DUO Bu...          0
# 124      Mozilla/5.0 (Linux; Android 5.0.2; ASUS_Z011D ...          0
# 128      Mozilla/5.0 (Linux; Android 6.0; LG-K350 Build...          0
# 132      Mozilla/5.0 (Linux; Android 4.4.2; 4035D Build...          0
# 135      Mozilla/5.0 (Linux; Android 4.4.2; HUAWEI Y625...          0
# ...                                                    ...        ...
# 5000213  Mozilla/5.0 (Linux; Android 5.1; FS504 Build/L...          0
# 5000249  Mozilla/5.0 (Linux; Android 4.4.2; GT-N7100 Bu...          0
# 5000289  Mozilla/5.0 (Linux; U; Android 4.1.1; ru-ru; M...         14
# 5000292  Mozilla/5.0 (Linux; Android 5.1.1; SM-G531H Bu...         14
# 5000314  Mozilla/5.0 (Linux; Android 5.0; Lenovo A1000 ...          0
# 5000339  Mozilla/5.0 (Linux; Android 5.1; SUPRA M72DG B...         14
# 5000349  Mozilla/5.0 (Linux; Android 5.1; Impress More ...          0
# 5000372  Mozilla/5.0 (Linux; Android 5.0; ASUS_Z00AD Bu...         14
# 5000432  Mozilla/5.0 (Linux; Android 7.0; SM-A310F Buil...          0
# 5000454  Mozilla/5.0 (Linux; Android 5.1.1; SM-J105H Bu...          0
# 5000455  Mozilla/5.0 (Linux; Android 5.1; LG-X220 Build...          0
# 5000517  Mozilla/5.0 (Linux; Android 5.1; VOX S501 3G V...         14
# 5000519  Mozilla/5.0 (Linux; Android 5.0.2; PSP3530DUO ...         14
# 5000548  Mozilla/5.0 (Linux; Android 5.1; Lenovo A1010a...          0
# 5000550  Mozilla/5.0 (Linux; Android 5.1.1; SM-J120F Bu...         14
# 5000573  Mozilla/5.0 (Linux; Android 5.1; Lenovo A2010-...         14
# 5000609  Mozilla/5.0 (Linux; Android 5.1; VOX S501 3G V...         14
# 5000614  Mozilla/5.0 (Linux; Android 6.0; LG-K350 Build...         14
# 5000622  Mozilla/5.0 (Linux; Android 5.1; Philips_S326 ...          0
# 5000632  Mozilla/5.0 (Linux; Android 4.4.2; I216X Build...          0
# 5000635  Mozilla/5.0 (Linux; Android 7.0; SM-A520F Buil...          0
# 5000656  Mozilla/5.0 (Linux; Android 5.1.1; SM-J105H Bu...         14
# 5000662  Mozilla/5.0 (Linux; Android 4.4.2; Philips I90...          0
# 5000663  Mozilla/5.0 (Linux; U; Android 4.2.2; ru-ru; L...          0
# 5000666  Mozilla/5.0 (Linux; U; Android 4.1.1; ru-ru; M...         14
# 5000671  Mozilla/5.0 (Linux; Android 4.4.2; SM-C101 Bui...          0
# 5000679  Mozilla/5.0 (Linux; Android 6.0; Lenovo TB3-85...          0
# 5000698  Mozilla/5.0 (Linux; Android 5.1; m2 Build/LMY4...          0
# 5000709  Mozilla/5.0 (Linux; Android 6.0.1; LG-K100 Bui...         14
# 5000714  Mozilla/5.0 (Linux; Android 5.1.1; SM-J105H Bu...         14
#
#         is_active rebill_uuid rebill_date rebill_error_code  rebill_status  \
# 0               0         NaN         NaN               NaN            NaN
# 1               0         NaN         NaN               NaN            NaN
# 12              0         NaN         NaN               NaN            NaN
# 16              0         NaN         NaN               NaN            NaN
# 20              0         NaN         NaN               NaN            NaN
# 23              0         NaN         NaN               NaN            NaN
# 29              0         NaN         NaN               NaN            NaN
# 31              0         NaN         NaN               NaN            NaN
# 33              0         NaN         NaN               NaN            NaN
# 36              0         NaN         NaN               NaN            NaN
# 46              0         NaN         NaN               NaN            NaN
# 48              0         NaN         NaN               NaN            NaN
# 51              0         NaN         NaN               NaN            NaN
# 55              0         NaN         NaN               NaN            NaN
# 76              0         NaN         NaN               NaN            NaN
# 81              0         NaN         NaN               NaN            NaN
# 83              0         NaN         NaN               NaN            NaN
# 85              0         NaN         NaN               NaN            NaN
# 89              0         NaN         NaN               NaN            NaN
# 90              0         NaN         NaN               NaN            NaN
# 103             0         NaN         NaN               NaN            NaN
# 107             0         NaN         NaN               NaN            NaN
# 110             0         NaN         NaN               NaN            NaN
# 117             0         NaN         NaN               NaN            NaN
# 118             0         NaN         NaN               NaN            NaN
# 123             0         NaN         NaN               NaN            NaN
# 124             0         NaN         NaN               NaN            NaN
# 128             0         NaN         NaN               NaN            NaN
# 132             0         NaN         NaN               NaN            NaN
# 135             0         NaN         NaN               NaN            NaN
# ...           ...         ...         ...               ...            ...
# 5000213         0         NaN         NaN               NaN            NaN
# 5000249         0         NaN         NaN               NaN            NaN
# 5000289         0         NaN         NaN               NaN            NaN
# 5000292         0         NaN         NaN               NaN            NaN
# 5000314         0         NaN         NaN               NaN            NaN
# 5000339         0         NaN         NaN               NaN            NaN
# 5000349         0         NaN         NaN               NaN            NaN
# 5000372         0         NaN         NaN               NaN            NaN
# 5000432         0         NaN         NaN               NaN            NaN
# 5000454         0         NaN         NaN               NaN            NaN
# 5000455         0         NaN         NaN               NaN            NaN
# 5000517         0         NaN         NaN               NaN            NaN
# 5000519         0         NaN         NaN               NaN            NaN
# 5000548         0         NaN         NaN               NaN            NaN
# 5000550         0         NaN         NaN               NaN            NaN
# 5000573         0         NaN         NaN               NaN            NaN
# 5000609         0         NaN         NaN               NaN            NaN
# 5000614         0         NaN         NaN               NaN            NaN
# 5000622         0         NaN         NaN               NaN            NaN
# 5000632         0         NaN         NaN               NaN            NaN
# 5000635         0         NaN         NaN               NaN            NaN
# 5000656         0         NaN         NaN               NaN            NaN
# 5000662         0         NaN         NaN               NaN            NaN
# 5000663         0         NaN         NaN               NaN            NaN
# 5000666         0         NaN         NaN               NaN            NaN
# 5000671         0         NaN         NaN               NaN            NaN
# 5000679         0         NaN         NaN               NaN            NaN
# 5000698         0         NaN         NaN               NaN            NaN
# 5000709         0         NaN         NaN               NaN            NaN
# 5000714         0         NaN         NaN               NaN            NaN
#
#          ua_black_list
# 0                    0
# 1                    0
# 12                   0
# 16                   1
# 20                   0
# 23                   0
# 29                   0
# 31                   0
# 33                   0
# 36                   0
# 46                   0
# 48                   0
# 51                   1
# 55                   0
# 76                   0
# 81                   0
# 83                   0
# 85                   0
# 89                   0
# 90                   0
# 103                  0
# 107                  0
# 110                  1
# 117                  0
# 118                  0
# 123                  1
# 124                  0
# 128                  0
# 132                  0
# 135                  0
# ...                ...
# 5000213              1
# 5000249              0
# 5000289              0
# 5000292              0
# 5000314              0
# 5000339              0
# 5000349              0
# 5000372              0
# 5000432              0
# 5000454              0
# 5000455              0
# 5000517              0
# 5000519              1
# 5000548              0
# 5000550              0
# 5000573              0
# 5000609              0
# 5000614              0
# 5000622              0
# 5000632              1
# 5000635              0
# 5000656              0
# 5000662              0
# 5000663              0
# 5000666              0
# 5000671              0
# 5000679              0
# 5000698              0
# 5000709              0
# 5000714              0
#
# [1263244 rows x 21 columns]

# %%
manual()

# %%
# оборачиваем фукнцию в фукнцию которую толкают фукнции - удолетворительно хороший результат. 
# работает как часы: 1 execute на инициацию алгоритма + 1 вызов на вывод реузльтата - статки.

def select():
    Bexc = df_1[df_1['query'].str.contains('exchange=%7Bexc%7D', na=False)]
    BEXCHANGE_ID = df_1[df_1['query'].str.contains('exchange=BEXCHANGE_ID', na=False)]
    EXCHANGE_ID = df_1[df_1['query'].str.contains('exchange=EXCHANGE_ID', na=False)]
    axonix = df_1[df_1['query'].str.contains('exchange=axonix', na=False)]
    smartyads = df_1[df_1['query'].str.contains('exchange=smartyads', na=False)]
    undef = df_1[df_1['query'].str.contains('exchange=undef', na=False)]
    arteebee = df_1[df_1['query'].str.contains('exchange=arteebee', na=False)]
    between = df_1[df_1['query'].str.contains('exchange=between', na=False)]
    clickky = df_1[df_1['query'].str.contains('exchange=clickky', na=False)]
    google = df_1[df_1['query'].str.contains('exchange=google', na=False)]
    gothamads = df_1[df_1['query'].str.contains('exchange=gothamads', na=False)]
    mobilda = df_1[df_1['query'].str.contains('exchange=mobilda', na=False)]
    repeater = df_1[df_1['query'].str.contains('exchange=repeater', na=False)]
    republer = df_1[df_1['query'].str.contains('exchange=republer', na=False)]
    sape = df_1[df_1['query'].str.contains('exchange=sape', na=False)]  
    clickky2 = df_1[df_1['query'].str.contains('exchange=clickky2', na=False)]
    exoclick = df_1[df_1['query'].str.contains('exchange=exoclick', na=False)]
    popcash = df_1[df_1['query'].str.contains('exchange=popcash', na=False)]
    popunder = df_1[df_1['query'].str.contains('exchange=popunder', na=False)]
    propeller = df_1[df_1['query'].str.contains('exchange=propeller', na=False)]
    yabbi = df_1[df_1['query'].str.contains('exchange=yabbi', na=False)]
    activerevenue = df_1[df_1['query'].str.contains('exchange=activerevenue', na=False)]
    fallback = df_1[df_1['query'].str.contains('exchange=fallback', na=False)]
    innex = df_1[df_1['query'].str.contains('exchange=innex', na=False)]
    juicy = df_1[df_1['query'].str.contains('exchange=juicy', na=False)]
    airpush = df_1[df_1['query'].str.contains('exchange=airpush', na=False)]
    leadbolt = df_1[df_1['query'].str.contains('exchange=leadbolt', na=False)]
    something = df_1[df_1['query'].str.contains('exchange=something', na=False)]
    hilltop = df_1[df_1['query'].str.contains('exchange=hilltop', na=False)]
    propellerads = df_1[df_1['query'].str.contains('exchange=propellerads', na=False)]
    mobicow = df_1[df_1['query'].str.contains('exchange=mobicow', na=False)]
    openx = df_1[df_1['query'].str.contains('exchange=openx', na=False)]
    smaato = df_1[df_1['query'].str.contains('exchange=smaato', na=False)]
    tonic = df_1[df_1['query'].str.contains('exchange=tonic', na=False)]
    traffichunt = df_1[df_1['query'].str.contains('exchange=traffichunt', na=False)]
    zeropark = df_1[df_1['query'].str.contains('exchange=zeropark', na=False)]
    admobile = df_1[df_1['query'].str.contains('exchange=admobile', na=False)]
    tapxx = df_1[df_1['query'].str.contains('exchange=tapxx', na=False)]
    teasernet = df_1[df_1['query'].str.contains('exchange=teasernet', na=False)]
    visitweb = df_1[df_1['query'].str.contains('exchange=visitweb', na=False)]
    epom = df_1[df_1['query'].str.contains('exchange=epom', na=False)]
    plugrush = df_1[df_1['query'].str.contains('exchange=plugrush', na=False)]
    kadam = df_1[df_1['query'].str.contains('exchange=kadam', na=False)]
    minimob = df_1[df_1['query'].str.contains('exchange=minimob', na=False)]
    peakadx = df_1[df_1['query'].str.contains('exchange=peakadx', na=False)]
    print('Bexc', len(Bexc), 'axonix', len(axonix), 'smartyads', len(smartyads), 'undef', len(undef),'arteebee', len(arteebee), 
                 'between', len(between), 'clickky', len(clickky), 'google', len(google), 'gothamads',len(gothamads), 'mobilda',len(mobilda),
                 'repeater',len(repeater), 'republer', len(republer), 'sape', len(sape), 'clickky2', len(clickky2),'exoclick',len(exoclick),
                 'popcash',len(popcash), 'popunder',len(popunder), 'propeller',len(propeller), 'yabbi',len(yabbi), 'activerevenue', len(activerevenue),
                'fallback', len(fallback), 'innex', len(innex), 'juicy',len(juicy), 'airpush', len(airpush), 'leadbolt', len(leadbolt),
                 'something', len(something), 'hilltop',len(hilltop), 'propellerads',len(propellerads), 'mobicow', len(mobicow),'openx',len(openx),
                 'smaato',len(smaato), 'tonic',len(tonic), 'traffichunt',len(traffichunt), 'zeropark', len(zeropark), 'admobile', len(admobile),
                 'tapxx', len(tapxx), 'teasernet', len(teasernet), 'visitweb', len(visitweb), 'BEXCHANGE_ID',len(BEXCHANGE_ID),
                 'EXCHANGE_ID',len(EXCHANGE_ID) ,'epom', len(epom), 'plugrush',len(plugrush), 'kadam', len(kadam),
                  'minimob', len(minimob), 'peakadx', len(peakadx), 'a_propellerads', len(a_propellerads))
    return Bexc,BEXCHANGE_ID,EXCHANGE_ID,axonix,smartyads,undef,arteebee,between,clickky,google,gothamads,mobilda,repeater,republer,sape,clickky2,exoclick, popcash,popunder,propeller,yabbi,activerevenue,fallback,innex,juicy,airpush, leadbolt,
    something, hilltop,propellerads,mobicow,openx, smaato, tonic,traffichunt,zeropark,admobile,tapxx,teasernet,visitweb, epom,
    plugrush,kadam, minimob,peakadx,a_propellerads

def warp_field_generator():
    for pony in select():
        yield pony

# запомните няши! warp_field_generator() конечно можно вызвать влоб внутри генератора pony_in_action(), но не нужно.
# если делать влоб - вывод алгоритма при вывозе pony_in_action() сведёться к первому датафрейму в списке и только к нему.
        
warp_portal = warp_field_generator()   

def pony_in_action():
    for warp in warp_portal:
        if len(warp) > 0:
            init = warp['date_init'].value_counts().sum()
            subs = warp['date_activation'].value_counts().sum()
            stops = warp['date_stop'].value_counts().sum()
            subs_active = warp['is_active'].value_counts()
            subs_fr_error = warp['error_code'].value_counts(normalize=True)
            subs_type_error = warp['error_code'].value_counts()
            rebills = warp['rebill_date'].value_counts().sum()
            rebills_status = warp['rebill_status'].value_counts()
            rebills_fr_error = warp['rebill_error_code'].value_counts(normalize=True)
            rebills_type_error = warp['rebill_error_code'].value_counts()
            users = warp['msisdn'].value_counts().sum()
            users_unic = warp['msisdn'].drop_duplicates().values.tolist()
            users_unic_source = warp['referrer'].drop_duplicates().values.tolist()
            users_ip = warp['ip'].values.tolist()
            users_unic_ip = warp['ip'].drop_duplicates().values.tolist()
            print('Число инитов', init,'Число подписок', subs, 'Число стопов', stops,'\n','Состояние подписок','\n',
                 subs_active,'\n', 
                 'Частоты ошибок по подпискам','\n',subs_fr_error,'\n', 'Типы ошибок по подпискам','\n', subs_type_error, '\n',
                 'Число ребиллов', rebills, '\n','Успешность ребильности', '\n',rebills_status, '\n',
                 'Частоты ошибок по ребиллам', '\n',rebills_fr_error, '\n','Типы ошибок по ребиллам', '\n',rebills_type_error,'Число юзеров', users,'\n',
                 'Число уникальных юезров', len(users_unic),'\n', 'Число уникальных источников', len(users_unic_source),'\n',
                 'Число ip адресов', len(users_ip),'\n', 'Число уникальных ip адресов',len(users_unic_ip))

# %%
pony_in_action()
# Out:
# Число инитов 2 Число подписок 0 Число стопов 0
#  Состояние подписок
#  0    2
# Name: is_active, dtype: int64
#  Частоты ошибок по подпискам
#  8    1.0
# Name: error_code, dtype: float64
#  Типы ошибок по подпискам
#  8    2
# Name: error_code, dtype: int64
#  Число ребиллов 0
#  Успешность ребильности
#  Series([], Name: rebill_status, dtype: int64)
#  Частоты ошибок по ребиллам
#  Series([], Name: rebill_error_code, dtype: float64)
#  Типы ошибок по ребиллам
#  Series([], Name: rebill_error_code, dtype: int64) Число юзеров 2
#  Число уникальных юезров 1
#  Число уникальных источников 1
#  Число ip адресов 2
#  Число уникальных ip адресов 1

# %%
pony_in_action()
# Out:
# Число инитов 1263244 Число подписок 44532 Число стопов 31403
#  Состояние подписок
#  0    1244649
# 1      13162
# 0       5433
# Name: is_active, dtype: int64
#  Частоты ошибок по подпискам
#  0      8.988010e-01
# 8      6.097555e-02
# 14     9.809665e-03
# 103    7.893170e-03
# 106    6.305987e-03
# 105    3.829031e-03
# 110    3.717413e-03
# 0      3.585214e-03
# 107    2.666152e-03
# 9      7.821134e-04
# 8      6.024173e-04
# 6      4.179715e-04
# 101    1.891954e-04
# 16     1.741548e-04
# 113    1.124090e-04
# 103    9.341030e-05
# 112    2.295677e-05
# 14     1.662387e-05
# 10     2.374838e-06
# 110    1.583225e-06
# 16     7.916127e-07
# 6      7.916127e-07
# Name: error_code, dtype: float64
#  Типы ошибок по подпискам
#  0      1135405
# 8        77027
# 14       12392
# 103       9971
# 106       7966
# 105       4837
# 110       4696
# 0         4529
# 107       3368
# 9          988
# 8          761
# 6          528
# 101        239
# 16         220
# 113        142
# 103        118
# 112         29
# 14          21
# 10           3
# 110          2
# 16           1
# 6            1
# Name: error_code, dtype: int64
#  Число ребиллов 44498
#  Успешность ребильности
#  1.0    41224
# 0.0     3274
# Name: rebill_status, dtype: int64
#  Частоты ошибок по ребиллам
#  0.0       0.926424
# 102.0     0.033597
# 52.0      0.021417
# 356.0     0.013731
# 51.0      0.003955
# 8.0       0.000854
# 1001.0    0.000022
# Name: rebill_error_code, dtype: float64
#  Типы ошибок по ребиллам
#  0.0       41224
# 102.0      1495
# 52.0        953
# 356.0       611
# 51.0        176
# 8.0          38
# 1001.0        1
# Name: rebill_error_code, dtype: int64 Число юзеров 1263244
#  Число уникальных юезров 3274
#  Число уникальных источников 17862
#  Число ip адресов 1263244
#  Число уникальных ip адресов 19851

# %%
# весь вывод смотреть не будем. инфа всётаки не виртуальная. тперь дело за тайтлами и подавлением вывода большиих значений.
